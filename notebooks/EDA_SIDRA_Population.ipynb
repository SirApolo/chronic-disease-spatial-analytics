# %%
import geobr as gbr

# %%
df = gbr.read_census_tract(code_tract="PR", year=2022)

# %%
df
# Out:
#          code_tract  code_muni name_muni name_neighborhood  code_neighborhood  \
# 0      4.100103e+14  4100103.0    Abatiá              None                NaN
# 1      4.100103e+14  4100103.0    Abatiá              None                NaN
# 2      4.100103e+14  4100103.0    Abatiá              None                NaN
# 3      4.100103e+14  4100103.0    Abatiá              None                NaN
# 4      4.100103e+14  4100103.0    Abatiá              None                NaN
# ...             ...        ...       ...               ...                ...
# 23772  4.128807e+14  4128807.0    Xambrê              None                NaN
# 23773  4.128807e+14  4128807.0    Xambrê              None                NaN
# 23774  4.128807e+14  4128807.0    Xambrê              None                NaN
# 23775  4.128807e+14  4128807.0    Xambrê              None                NaN
# 23776  4.128807e+14  4128807.0    Xambrê              None                NaN
#
# ...

# %%
df.columns.tolist()
# Out:
# ['code_tract',
#  'code_muni',
#  'name_muni',
#  'name_neighborhood',
#  'code_neighborhood',
#  'code_subdistrict',
#  'name_subdistrict',
#  'code_district',
#  'name_district',
#  'code_urban_concentration',
#  'name_urban_concentration',
#  'code_state',
#  'name_state',
#  'code_immediate',
#  'name_immediate',
#  'code_intermediate',
#  'name_intermediate',
#  'code_region',
#  'name_region',
#  'situacao',
#  'code_situacao',
#  'code_type',
#  'area_km2',
#  'geometry']

# %%
df1 = gbr.read_statistical_grid(code_grid="PR", year=2010)

# %%
df1
# Out:
#                  ID_UNICO       nome_1KM       nome_5KM       nome_10KM  \
# 0        200ME48190N88252  1KME4819N8825  5KME4815N8825  10KME4810N8820
# 1        200ME48192N88252  1KME4819N8825  5KME4815N8825  10KME4810N8820
# 2        200ME48194N88252  1KME4819N8825  5KME4815N8825  10KME4810N8820
# 3        200ME48196N88252  1KME4819N8825  5KME4815N8825  10KME4810N8820
# 4        200ME48198N88252  1KME4819N8825  5KME4815N8825  10KME4810N8820
# ...                   ...            ...            ...             ...
# 1220881     1KME5799N8845  1KME5799N8845  5KME5795N8845  10KME5790N8840
# 1220882     1KME5799N8846  1KME5799N8846  5KME5795N8845  10KME5790N8840
# 1220883     1KME5799N8847  1KME5799N8847  5KME5795N8845  10KME5790N8840
# 1220884     1KME5799N8848  1KME5799N8848  5KME5795N8845  10KME5790N8840
# 1220885     1KME5799N8849  1KME5799N8849  5KME5795N8845  10KME5790N8840
#
#               nome_50KM       nome_100KM       nome_500KM QUADRANTE  MASC  \
# ...

# %%
import sidrapy

# %%
data = sidrapy.get_table(
                table_code="4709",
                territorial_level="6",
                ibge_territorial_code="all",
                variable="93"
            )

# %%
data
# Out:
#                               NC                 NN  \
# 0     Nível Territorial (Código)  Nível Territorial
# 1                              6          Município
# 2                              6          Município
# 3                              6          Município
# 4                              6          Município
# ...                          ...                ...
# 5566                           6          Município
# 5567                           6          Município
# 5568                           6          Município
# 5569                           6          Município
# 5570                           6          Município
#
#                               MC                 MN        V  \
# 0     Unidade de Medida (Código)  Unidade de Medida    Valor
# 1                             45            Pessoas    21494
# 2                             45            Pessoas    96833
# 3                             45            Pessoas     5351
# ...

# %%
df = data[1:].copy()

# %%
df
# Out:
#      NC         NN  MC       MN        V      D1C                         D1N  \
# 1     6  Município  45  Pessoas    21494  1100015  Alta Floresta D'Oeste - RO
# 2     6  Município  45  Pessoas    96833  1100023              Ariquemes - RO
# 3     6  Município  45  Pessoas     5351  1100031                 Cabixi - RO
# 4     6  Município  45  Pessoas    86887  1100049                 Cacoal - RO
# 5     6  Município  45  Pessoas    15890  1100056             Cerejeiras - RO
# ...  ..        ...  ..      ...      ...      ...                         ...
# 5566  6  Município  45  Pessoas    14956  5222005             Vianópolis - GO
# 5567  6  Município  45  Pessoas     8768  5222054         Vicentinópolis - GO
# 5568  6  Município  45  Pessoas     4215  5222203               Vila Boa - GO
# 5569  6  Município  45  Pessoas     5815  5222302          Vila Propício - GO
# 5570  6  Município  45  Pessoas  2817381  5300108               Brasília - DF
#
# ...

# %%
df[["D1N", "UF"]] = df["D1N"].str.split(" - ", n=1, expand=True)

# %%
df
# Out:
#      NC         NN  MC       MN        V      D1C                    D1N D2C  \
# 1     6  Município  45  Pessoas    21494  1100015  Alta Floresta D'Oeste  93
# 2     6  Município  45  Pessoas    96833  1100023              Ariquemes  93
# 3     6  Município  45  Pessoas     5351  1100031                 Cabixi  93
# 4     6  Município  45  Pessoas    86887  1100049                 Cacoal  93
# 5     6  Município  45  Pessoas    15890  1100056             Cerejeiras  93
# ...  ..        ...  ..      ...      ...      ...                    ...  ..
# 5566  6  Município  45  Pessoas    14956  5222005             Vianópolis  93
# 5567  6  Município  45  Pessoas     8768  5222054         Vicentinópolis  93
# 5568  6  Município  45  Pessoas     4215  5222203               Vila Boa  93
# 5569  6  Município  45  Pessoas     5815  5222302          Vila Propício  93
# 5570  6  Município  45  Pessoas  2817381  5300108               Brasília  93
#
#                       D2N   D3C   D3N  UF
# ...

# %%
df.loc[df["D1N"] == "Curitiba - PR"]
# Out:
#      NC         NN  MC       MN        V      D1C            D1N D2C  \
# 4006  6  Município  45  Pessoas  1773718  4106902  Curitiba - PR  93
#
#                       D2N   D3C   D3N  UF
# 4006  População residente  2022  2022  RO

# %%
dfpr = df.loc[df["UF"] == "PR"]

# %%
dfpr = df[df["UF"] == "PR"]

# %%
dfpr
# Out:
#      NC         NN  MC       MN       V      D1C                  D1N D2C  \
# 3913  6  Município  45  Pessoas    7241  4100103               Abatiá  93
# 3914  6  Município  45  Pessoas    6256  4100202         Adrianópolis  93
# 3915  6  Município  45  Pessoas   10233  4100301        Agudos do Sul  93
# 3916  6  Município  45  Pessoas  119825  4100400  Almirante Tamandaré  93
# 3917  6  Município  45  Pessoas    3590  4100459   Altamira do Paraná  93
# ...  ..        ...  ..      ...     ...      ...                  ...  ..
# 4307  6  Município  45  Pessoas    3055  4128625         Alto Paraíso  93
# 4308  6  Município  45  Pessoas    5697  4128633       Doutor Ulysses  93
# 4309  6  Município  45  Pessoas    3811  4128658              Virmond  93
# 4310  6  Município  45  Pessoas    9706  4128708             Vitorino  93
# 4311  6  Município  45  Pessoas    5798  4128807               Xambrê  93
#
#                       D2N   D3C   D3N  UF
# ...

# %%
dfpr = dfpr.reset_index(drop=True)

# %%
dfpr
# Out:
#     NC         NN  MC       MN       V      D1C                  D1N D2C  \
# 0    6  Município  45  Pessoas    7241  4100103               Abatiá  93
# 1    6  Município  45  Pessoas    6256  4100202         Adrianópolis  93
# 2    6  Município  45  Pessoas   10233  4100301        Agudos do Sul  93
# 3    6  Município  45  Pessoas  119825  4100400  Almirante Tamandaré  93
# 4    6  Município  45  Pessoas    3590  4100459   Altamira do Paraná  93
# ..  ..        ...  ..      ...     ...      ...                  ...  ..
# 394  6  Município  45  Pessoas    3055  4128625         Alto Paraíso  93
# 395  6  Município  45  Pessoas    5697  4128633       Doutor Ulysses  93
# 396  6  Município  45  Pessoas    3811  4128658              Virmond  93
# 397  6  Município  45  Pessoas    9706  4128708             Vitorino  93
# 398  6  Município  45  Pessoas    5798  4128807               Xambrê  93
#
#                      D2N   D3C   D3N  UF
# 0    População residente  2022  2022  PR
# ...

# %%
dfpr[dfpr["D1N"] == "Foz do Iguaçu"]
# Out:
#      NC         NN  MC       MN       V      D1C            D1N D2C  \
# 4031  6  Município  45  Pessoas  285415  4108304  Foz do Iguaçu  93
#
#                       D2N   D3C   D3N  UF
# 4031  População residente  2022  2022  PR
